# %%
import pandas as pd

# %%
df = pd.read_excel('iris.xlsx', engine='openpyxl')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
rows = df.shape[0]
columns = df.shape[1]
print(rows)
print(columns)
# Out:
# 150
# 5

# %%
df1 = pd.read_csv('iris.csv')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#cuz it don't have the files that's why it error
df2 = pd.read_json('iris.json')
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#must create new folder
df.to_excel('Dataset/excel.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-edd2db9e2c9c> in <module>
#       1 #must create new folder
# ----> 2 df.to_excel('Dataset/excel.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2187             inf_rep=inf_rep,
#    2188         )
# -> 2189         formatter.write(
#    2190             excel_writer,
#    2191             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     813             # abstract class 'ExcelWriter' with abstract attributes 'engine',
# ...

# %%
df.to_csv('Dataset/excel.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-93d6cc77d427> in <module>
# ----> 1 df.to_csv('Dataset/excel.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
# ...

# %%
df.to_json('Dataset/excel.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-83373c1cd1fd> in <module>
# ----> 1 df.to_json('Dataset/excel.json')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#    2464         indent = indent or 0
#    2465
# -> 2466         return json.to_json(
#    2467             path_or_buf=path_or_buf,
#    2468             obj=self,
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#     100     if path_or_buf is not None:
#     101         # apply compression and byte/text conversion
# --> 102         with get_handle(
# ...

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.loc[3:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df[['sepal_length', 'sepal_width', 'species']]
# Out:
#      sepal_length  sepal_width    species
# 0             5.1          3.5     setosa
# 1             4.9          3.0     setosa
# 2             4.7          3.2     setosa
# 3             4.6          3.1     setosa
# 4             5.0          3.6     setosa
# ..            ...          ...        ...
# 145           6.7          3.0  virginica
# 146           6.3          2.5  virginica
# 147           6.5          3.0  virginica
# 148           6.2          3.4  virginica
# 149           5.9          3.0  virginica
#
# [150 rows x 3 columns]

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df = pd.read_excel('dummy_data.xlsx', engine='openpyxl')
df
# Out:
#    Sno     Name   Age  Height(cm)  Unnamed: 4
# 0    1     John  25.0       160.0         NaN
# 1    2    Jimmy  26.0       163.0         NaN
# 2    3  Felicia  28.0       154.0         NaN
# 3    4   Sophia   NaN       143.0         NaN
# 4    5      Bob   NaN         NaN         NaN
# 5    6    Billy  30.0       156.0         NaN
# 6    7     Kate  31.0       160.0         NaN
# 7    8     Will  29.0         NaN         NaN
# 8    9    Scott   NaN       148.0         NaN

# %%
df = pd.read_excel('dummy_data.xlsx', engine='openpyxl', index_col=0)
df
# Out:
#         Name   Age  Height(cm)  Unnamed: 4
# Sno
# 1       John  25.0       160.0         NaN
# 2      Jimmy  26.0       163.0         NaN
# 3    Felicia  28.0       154.0         NaN
# 4     Sophia   NaN       143.0         NaN
# 5        Bob   NaN         NaN         NaN
# 6      Billy  30.0       156.0         NaN
# 7       Kate  31.0       160.0         NaN
# 8       Will  29.0         NaN         NaN
# 9      Scott   NaN       148.0         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 1 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Age         6 non-null      float64
#  2   Height(cm)  7 non-null      float64
#  3   Unnamed: 4  0 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 360.0+ bytes

# %%
df.drop('Unnamed: 4', axis = 'columns',inplace = True)

# %%
rows = df.shape[0]
columns = df.shape[1]
print(rows)
print(columns)
# Out:
# 9
# 3

# %%
df.isna()
# Out:
#       Name    Age  Height(cm)
# Sno
# 1    False  False       False
# 2    False  False       False
# 3    False  False       False
# 4    False   True       False
# 5    False   True        True
# 6    False  False       False
# 7    False  False       False
# 8    False  False        True
# 9    False   True       False

# %%
df.notna()
# Out:
#      Name    Age  Height(cm)
# Sno
# 1    True   True        True
# 2    True   True        True
# 3    True   True        True
# 4    True  False        True
# 5    True  False       False
# 6    True   True        True
# 7    True   True        True
# 8    True   True       False
# 9    True  False        True

# %%
df.isnull()
# Out:
#       Name    Age  Height(cm)
# Sno
# 1    False  False       False
# 2    False  False       False
# 3    False  False       False
# 4    False   True       False
# 5    False   True        True
# 6    False  False       False
# 7    False  False       False
# 8    False  False        True
# 9    False   True       False

# %%
df.isna().sum()
# Out:
# Name          0
# Age           3
# Height(cm)    2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           3
# Height(cm)    2
# dtype: int64

# %%
df.notna().sum()
# Out:
# Name          9
# Age           6
# Height(cm)    7
# dtype: int64

# %%
df = pd.read_excel('dummy_data.xlsx', engine='openpyxl', index_col=0)
df
# Out:
#         Name   Age  Height(cm)  Unnamed: 4
# Sno
# 1       John  25.0       160.0         NaN
# 2      Jimmy  26.0       163.0         NaN
# 3    Felicia  28.0       154.0         NaN
# 4     Sophia   NaN       143.0         NaN
# 5        Bob   NaN         NaN         NaN
# 6      Billy  30.0       156.0         NaN
# 7       Kate  31.0       160.0         NaN
# 8       Will  29.0         NaN         NaN
# 9      Scott   NaN       148.0         NaN

# %%
df.drop('Unnamed: 4', axis = 'columns',inplace = True)

# %%
df.dropna()
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0

# %%
remoned_nd_df = df.dropna()
remoned_nd_df
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0

# %%
df = pd.read_csv('dummy_missing_majority.csv', index_col = 0)
df
# Out:
#         Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1       John  25.0       160.0        80.0     USA  New York
# 2      Jimmy  26.0       163.0         NaN      UK    London
# 3    Felicia  28.0       154.0         NaN     USA     Miami
# 4     Sophia   NaN       143.0         NaN     NaN       NaN
# 5        Bob   NaN         NaN         NaN     NaN       NaN
# 6      Billy  30.0       156.0         NaN  France     Paris
# 7       Kate  31.0       160.0         NaN   Italy      Rome
# 8       Will  29.0         NaN         NaN  Russia    Moscow
# 9      Scott   NaN       148.0         NaN     NaN       NaN

# %%
df.dropna()
# Out:
#      Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1    John  25.0       160.0        80.0     USA  New York

# %%
df.dropna(thresh = 4)
# Out:
#         Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1       John  25.0       160.0        80.0     USA  New York
# 2      Jimmy  26.0       163.0         NaN      UK    London
# 3    Felicia  28.0       154.0         NaN     USA     Miami
# 6      Billy  30.0       156.0         NaN  France     Paris
# 7       Kate  31.0       160.0         NaN   Italy      Rome
# 8       Will  29.0         NaN         NaN  Russia    Moscow

# %%
df.dropna(thresh = 2)
# Out:
#         Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1       John  25.0       160.0        80.0     USA  New York
# 2      Jimmy  26.0       163.0         NaN      UK    London
# 3    Felicia  28.0       154.0         NaN     USA     Miami
# 4     Sophia   NaN       143.0         NaN     NaN       NaN
# 6      Billy  30.0       156.0         NaN  France     Paris
# 7       Kate  31.0       160.0         NaN   Italy      Rome
# 8       Will  29.0         NaN         NaN  Russia    Moscow
# 9      Scott   NaN       148.0         NaN     NaN       NaN

# %%
df.dropna(thresh = 6)
# Out:
#      Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1    John  25.0       160.0        80.0     USA  New York

# %%
# drop row with over 60% empty values
percentage = 0.6 
value = percentage * len(df.columns)
print(int(value))
# Out:
# 3

# %%
df
# Out:
#         Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1       John  25.0       160.0        80.0     USA  New York
# 2      Jimmy  26.0       163.0         NaN      UK    London
# 3    Felicia  28.0       154.0         NaN     USA     Miami
# 4     Sophia   NaN       143.0         NaN     NaN       NaN
# 5        Bob   NaN         NaN         NaN     NaN       NaN
# 6      Billy  30.0       156.0         NaN  France     Paris
# 7       Kate  31.0       160.0         NaN   Italy      Rome
# 8       Will  29.0         NaN         NaN  Russia    Moscow
# 9      Scott   NaN       148.0         NaN     NaN       NaN

# %%
df.dropna(axis=0, thresh= value)
# Out:
#         Name   Age  Height(cm)  Marks(100) Country      City
# Sno
# 1       John  25.0       160.0        80.0     USA  New York
# 2      Jimmy  26.0       163.0         NaN      UK    London
# 3    Felicia  28.0       154.0         NaN     USA     Miami
# 6      Billy  30.0       156.0         NaN  France     Paris
# 7       Kate  31.0       160.0         NaN   Italy      Rome
# 8       Will  29.0         NaN         NaN  Russia    Moscow

# %%
df = pd.read_excel('dummy_data.xlsx', engine='openpyxl', index_col=0)
df
# Out:
#         Name   Age  Height(cm)  Unnamed: 4
# Sno
# 1       John  25.0       160.0         NaN
# 2      Jimmy  26.0       163.0         NaN
# 3    Felicia  28.0       154.0         NaN
# 4     Sophia   NaN       143.0         NaN
# 5        Bob   NaN         NaN         NaN
# 6      Billy  30.0       156.0         NaN
# 7       Kate  31.0       160.0         NaN
# 8       Will  29.0         NaN         NaN
# 9      Scott   NaN       148.0         NaN

# %%
df.drop('Unnamed: 4', axis = 'columns',inplace = True)
df
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia   NaN       143.0
# 5        Bob   NaN         NaN
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0         NaN
# 9      Scott   NaN       148.0

# %%
df.fillna(-1)
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia  -1.0       143.0
# 5        Bob  -1.0        -1.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0        -1.0
# 9      Scott  -1.0       148.0

# %%
df.fillna(0)
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia   0.0       143.0
# 5        Bob   0.0         0.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0         0.0
# 9      Scott   0.0       148.0

# %%
df.fillna(0, inplace= True)
df
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia   0.0       143.0
# 5        Bob   0.0         0.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0         0.0
# 9      Scott   0.0       148.0

# %%
df = pd.read_excel('dummy_data.xlsx', engine='openpyxl', index_col=0)
df.drop('Unnamed: 4', axis = 'columns',inplace = True)
df
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia   NaN       143.0
# 5        Bob   NaN         NaN
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0         NaN
# 9      Scott   NaN       148.0

# %%
# backward fill
df.bfill()
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia  30.0       143.0
# 5        Bob  30.0       156.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0       148.0
# 9      Scott   NaN       148.0

# %%
# forward fill
df.ffill()
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia  28.0       143.0
# 5        Bob  28.0       143.0
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0       160.0
# 9      Scott  29.0       148.0

# %%
df
# Out:
#         Name   Age  Height(cm)
# Sno
# 1       John  25.0       160.0
# 2      Jimmy  26.0       163.0
# 3    Felicia  28.0       154.0
# 4     Sophia   NaN       143.0
# 5        Bob   NaN         NaN
# 6      Billy  30.0       156.0
# 7       Kate  31.0       160.0
# 8       Will  29.0         NaN
# 9      Scott   NaN       148.0

# %%
mean_age = df['Age'].mean()
mean_age
# Out:
# 28.166666666666668

# %%
mean_height = df['Height(cm)'].mean()
print(mean_height)
# Out:
# 154.85714285714286

# %%
df['Age'].fillna(mean_age)
# Out:
# Sno
# 1    25.000000
# 2    26.000000
# 3    28.000000
# 4    28.166667
# 5    28.166667
# 6    30.000000
# 7    31.000000
# 8    29.000000
# 9    28.166667
# Name: Age, dtype: float64

# %%
df['Height(cm)'].fillna(mean_height)
# Out:
# Sno
# 1    160.000000
# 2    163.000000
# 3    154.000000
# 4    143.000000
# 5    154.857143
# 6    156.000000
# 7    160.000000
# 8    154.857143
# 9    148.000000
# Name: Height(cm), dtype: float64

# %%
df = pd.read_csv('dummy_age_weight.csv')
df
# Out:
#     Gender  Weight(kg)
# 0     Male        70.0
# 1   Female        55.0
# 2     Male        65.0
# 3   Female         NaN
# 4   Female        60.0
# 5     Male         NaN
# 6   Female        52.0
# 7   Female        53.0
# 8     Male        85.0
# 9     Male        75.0
# 10    Male         NaN
# 11  Female        68.0

# %%
df.groupby('Gender')

# %%
for x in df.groupby('Gender'):
    print('Printing group')
    print(x)
    print(x[1].mean())
    print()
# Out:
# Printing group
# ('Female',     Gender  Weight(kg)
# 1   Female        55.0
# 3   Female         NaN
# 4   Female        60.0
# 6   Female        52.0
# 7   Female        53.0
# 11  Female        68.0)
# Weight(kg)    57.6
# dtype: float64
#
# Printing group
# ('Male',    Gender  Weight(kg)
# 0    Male        70.0
# 2    Male        65.0
# 5    Male         NaN
# 8    Male        85.0
# 9    Male        75.0
# 10   Male         NaN)
# Weight(kg)    73.75
# dtype: float64

# %%
df['Weight(kg)'] = df.groupby('Gender').transform(lambda x: x.fillna(x.mean()))
df
# Out:
#     Gender  Weight(kg)
# 0     Male       70.00
# 1   Female       55.00
# 2     Male       65.00
# 3   Female       57.60
# 4   Female       60.00
# 5     Male       73.75
# 6   Female       52.00
# 7   Female       53.00
# 8     Male       85.00
# 9     Male       75.00
# 10    Male       73.75
# 11  Female       68.00
